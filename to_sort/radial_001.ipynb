# %%
import lib.calc as calc
import numpy as np
import matplotlib.pyplot as plt

# %%
sdata = np.load('../stitched_data/42_45.npy')
sdata2 = np.load('../stitched_data/247_250.npy')
scans =[42,43,44,45]
scans2 = [247,248,249,250]

# %%
qx, qy, qz = calc.qconvert_e16014('../data/hc3211.h5',scans)
# Out:
# Cen pix corrected by mpxz: 0.0; mpxy: 0.0
# Offsets used: defaultdict(<class 'float'>, {'rhz': 0.0, 'eta': 0.0, 'delta': 0.0, 'nu': 0.0, 'rhy': 0.0, 'rhx': 0.0, 'mu': 0.0, 'phi': 0.0})

# %%
qx2, qy2, qz2 = calc.qconvert_e16014('../data/hc3211.h5',scans2)
# Out:
# Cen pix corrected by mpxz: 0.0; mpxy: 0.0
# Offsets used: defaultdict(<class 'float'>, {'rhz': 0.0, 'eta': 0.0, 'delta': 0.0, 'nu': 0.0, 'rhy': 0.0, 'rhx': 0.0, 'mu': 0.0, 'phi': 0.0})

# %%
from id01lib.process import rebin

# %%
iroi = np.s_[350:610,370:500,130:230]
# iroi = np.s_[230:290,250:300,100:170]

# %%
qabs = np.sqrt(qx[iroi]**2 + qy[iroi]**2 + qz[iroi]**2) # the length
x, y = rebin.rebin1d(qabs, sdata[iroi],bins=500)
d=2*np.pi/x

# %%
qabs2 = np.sqrt(qx2[iroi]**2 + qy2[iroi]**2 + qz2[iroi]**2) # the length
x2, y2 = rebin.rebin1d(qabs2, sdata2[iroi],bins=100)
d2=2*np.pi/x2

# %%
# %matplotlib notebook
plt.plot(d,y)
# plt.plot(d2,y2)
# plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.pcolormesh(np.log(qy[iroi][0],qz[iroi][0],sdata[iroi][0]),cmap='jet')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-a5771de0efbf> in <module>()
# ----> 1 plt.pcolormesh(np.log(qy[iroi][0],qz[iroi][0],sdata[iroi][0]),cmap='jet')
#
# ValueError: invalid number of arguments

# %%
qy[iroi].shape
# Out:
# (260, 130, 100)
