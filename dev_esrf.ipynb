# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
from ipywidgets import interact
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# %cd '/Users/ezatterin/Documents/UCL_phd/scripts/python/esrf_python'
# Out:
# /Users/ezatterin/OneDrive - University College London/OneDrive Synced Docs/UCL_phd/scripts/python/esrf_python

# %%
f = h5py.File('testme6.h5')
f.keys()
# Out:
# [u'scan_0006',
#  u'scan_0015',
#  u'scan_0022',
#  u'scan_0024',
#  u'scan_0033',
#  u'scan_0042',
#  u'scan_0056']

# %%
data = []
for key in f.keys():
    data.append(f[key + '/data/image_data/'].value)

# %%
del data[2]

# %%
@interact(i=(0,data[0].shape[0]))
def plot_slice(i):
    fig, ax = plt.subplots(2,3,figsize=(12,6))
    for index, scan in enumerate(data):

        ax = ax.flatten()
        ax[index].imshow(np.log(data[index][i]))
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:7: RuntimeWarning: divide by zero encountered in log
