# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %matplotlib notebook

# %%
# %cd ~/Documents/beam/20180515_HC3501/e17089
# Out:
# /users/zatterin/Documents/beam/20180515_HC3501/e17089

# %%
im = np.array(Image.open('img_0495.tif'))

# %%
# %matplotlib notebook
# plt.figure(figsize=(10,10))
plt.imshow(np.log(im), vmax=7.7)
# Out:
# <img src="data:image/png;base64,..." width="1018.7499848194423">
