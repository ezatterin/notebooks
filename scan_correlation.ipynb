# %%
import h5py
from ipywidgets import interact
import xrayutilities_id01_functions as id01
import xrayutilities as xu
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
d = '../h5_files/'
# !ls {d} | grep h5
# Out:
# 20161115_E16019.h5
# 20161115_E16019_fast_00009.h5
# 20161115_E16088.h5

# %%
fname = '20161115_E16088.h5'

# %%
f = h5py.File(d+fname)

# %%
f.keys()
# Out:
# [u'scan_0010']

# %%
scan = f['scan_0010/data/image_data']
scan.shape
# Out:
# (110, 516, 516)

# %% [markdown]
# Raw data:

# %%
@interact(i=(0,scan.shape[0]))
def plt_scan(i):
    plt.imshow(np.log(scan[i]),interpolation='none')

# %%
np.correlate??

# %%
from scipy.signal import correlate2d, fftconvolve

# %%
@interact(i=(0,scan.shape[0]))
def plt_test(i):
    im = fftconvolve(scan[0],scan[i],mode='same')
    plt.imshow(im,interpolation='none')

# %%
plt.imshow(test)

# %%
test = correlate2d(scan[0],scan[1],mode='same')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5715004ca411> in <module>()
# ----> 1 test = correlate2d(scan[0],scan[1],mode='same')
#
# /usr/local/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in correlate2d(in1, in2, mode, boundary, fillvalue)
#     799         warnings.simplefilter('ignore', np.ComplexWarning)
#     800         # FIXME: some cast generates a warning here
# --> 801         out = sigtools._convolve2d(in1, in2, 0, val, bval, fillvalue)
#     802
#     803     return out
#
# KeyboardInterrupt:

# %%
plt.imshow(test,interpolation='none')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-dfe1d8da2652> in <module>()
# ----> 1 plt.imshow(test,interpolation='none')
#
# NameError: name 'test' is not defined

# %%
plt.imshow(test2)

# %%
test.max(), test2.max()
# Out:
# (49185560.0, 49955332.0)
