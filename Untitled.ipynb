# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import pyFAI as pf

from pyFAI.gui import jupyter
# Out:
# /users/zatterin/Envs/py3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
fname = '/data/visitor/hc3737/bm02/analysis/e17062/e17062_qconv.h5'
with h5py.File(fname, 'r') as h5f:
    i = h5f['29/gint'].value

# %%
projz.shape
# Out:
# (526, 576)

# %%
idx1, idx2 = 370, 420

projx = i.sum(0)
projz = i[:,:,idx1:idx2].sum(2)

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5))

ax1.imshow(np.log(projx.T), origin='lower')
ax1.axhline(idx1, c='C1')
ax1.axhline(idx2, c='C1')

ax2.imshow(np.log(projz))
# Out:
# /users/zatterin/Envs/py3/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
#
# /users/zatterin/Envs/py3/lib/python3.5/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':

# %%
def cart2pol(x, y):
    rho = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)

# %%
from skimage import io

# %%
im = io.imread('/users/zatterin/Desktop/Picture1.jpg')

# %%
plt.imshow(im[:,:,0])
plt.colorbar()

# %%
im = im[:,:,0]

# %%
im = im/im.max()
fftim = np.fft.fftshift(np.fft.fft2(im))

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,8))

ax1.imshow(im)
ax2.imshow(fftim.real,vmax=100,vmin=-100)

# %%
fftim.real.min()
# Out:
# -4011.3903007994845
